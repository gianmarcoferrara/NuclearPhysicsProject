# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f1(x):
    return np.exp(-x) * np.sin(2 * np.pi * x)

# Generate x values
x = np.linspace(0, 5, 100)  # From 0 to 5 with 100 points

# Compute y values for the first function
y1 = f1(x)

# Create the first plot in the first figure
plt.figure(1)  # This creates a new figure
plt.plot(x, y1, label=r'$e^{-x} \sin(2\pi x)$', color='b')
plt.xlabel("x")
plt.ylabel("y")
plt.title("First Function Plot")
plt.grid(True)
plt.legend()

# Now, plot the second function in a new figure
def f2(x):
    return np.exp(-x) * np.cos(2 * np.pi * x)

# Compute y values for the second function
y2 = f2(x)

plt.figure(2)  # This creates a new figure
plt.plot(x, y2, label=r'$e^{-x} \cos(2\pi x)$', color='r')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Second Function Plot")
plt.grid(True)
plt.legend()

# Show all figures
plt.show()
